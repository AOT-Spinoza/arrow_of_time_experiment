# %%
import sys
import os
import numpy as np
import cortex
import matplotlib.pyplot as plt
import pickle

# %%
test_data_paths = [f'/tank/shared/2022/arrow_of_time/arrow_of_time/aot/analysis/glmsingle/outputtest/{task}/TYPED_FITHRF_GLMDENOISE_RR.npy' for task in [72,90,80,"all"]]
test_data = [np.load(test_data_path,allow_pickle=True).item() for test_data_path in test_data_paths]

for index in range(len(test_data)):
    pcregressors = test_data[index]['pcregressors']
    print(len(pcregressors))
    for regressor in pcregressors:
        print(regressor.shape)
        #plot the first 10 regressors
        for i in range(9):
            pctimecourse = regressor[:,i]
            #plot pc time course for each regressor
            plt.plot(pctimecourse)
            plt.show()
# Out:
# 2
# (202, 11)
# (202, 11)
# 2
# (228, 11)
# (228, 11)
# 2
# (218, 11)
# (218, 11)
# 6
# (202, 11)
# (202, 11)
# (228, 11)
# (228, 11)
# (218, 11)
# (218, 11)
