# %%
import sys
import os
import numpy as np
import cortex
import matplotlib.pyplot as plt
import pickle

# %%
#test_data_path = '/tank/shared/2022/arrow_of_time/arrow_of_time_exp/aot/analysis/glmsingle/outputs/mainexp/sub-002_ses-01_fsaverage/TYPED_FITHRF_GLMDENOISE_RR.npy'
test_data_path = '/tank/shared/2022/arrow_of_time/arrow_of_time_exp/aot/analysis/glmsingle/outputs/mainexp/sub-002_ses-01_fsaverage/TYPEC_FITHRF_GLMDENOISE.npy'
#test_data_path = '/tank/shared/2022/arrow_of_time/arrow_of_time_exp/aot/analysis/glmsingle/outputs/mainexp/sub-002_ses-01_fsaverage/TYPEB_FITHRF.npy'
test_data = np.load(test_data_path,allow_pickle=True).item()
print(test_data.keys())

#tasks = ['all']


for key in test_data:
    print(key)
    if key == 'pcnum':
        print(test_data[key])
print('------------------')
print()

if 'TYPED' in test_data_path:
    #onoffR2 = test_data['onoffR2']
    R2 = test_data['R2']
    #meanvol = test_data['meanvol']
    #
    #noisepool = test_data['noisepool']
    #HRFindex = test_data['HRFindex']
    #fracvalue = test_data['FRACvalue']
    # print(test_data['meanvol'])
    #print(test_data['noisepool'].shape)
    #print(test_data['R2'].shape)
    #print(noisepool)

    betas = test_data['betasmd']
    print(betas.shape)
    # #switch the first and second dimension
    # betas = np.swapaxes(betas,0,1)

    betamean = np.mean(betas,axis=1)
    print(betamean.shape)

    # dataslice = data_for_plot[10]
    # print(dataslice.shape)

    data_to_plot1=cortex.Vertex(data=betamean,subject='fsaverage_tk',cmap="viridis")
    data_to_plot2=cortex.Vertex(data=R2,subject='fsaverage_tk', cmap='inferno')
    #data_to_plot3=cortex.Vertex(data=HRFindex,subject='fsaverage_tk',cmap="jet")
    #data_to_plot4=cortex.Vertex(data=fracvalue,subject='fsaverage_tk',cmap="copper")
    data_to_plot5=cortex.Vertex(data=noisepool,subject='fsaverage_tk',cmap="RdBu_r",vmin=0,vmax=1)
    flatmap=cortex.quickshow(data_to_plot1)
    flatmap=cortex.quickshow(data_to_plot2)
    #flatmap=cortex.quickshow(data_to_plot3)
    #flatmap=cortex.quickshow(data_to_plot4)
    flatmap=cortex.quickshow(data_to_plot5)
    #plt.show()
elif 'TYPEC' in test_data_path:
    #onoffR2 = test_data['onoffR2']
    R2 = test_data['R2']
    #meanvol = test_data['meanvol']
    #
    #noisepool = test_data['noisepool']
    #HRFindex = test_data['HRFindex']
    #fracvalue = test_data['FRACvalue']
    # print(test_data['meanvol'])
    #print(test_data['noisepool'].shape)
    #print(test_data['R2'].shape)
    #print(noisepool)

    betas = test_data['betasmd']
    print(betas.shape)
    # #switch the first and second dimension
    # betas = np.swapaxes(betas,0,1)

    betamean = np.mean(betas,axis=1)
    print(betamean.shape)

    # dataslice = data_for_plot[10]
    # print(dataslice.shape)

    data_to_plot1=cortex.Vertex(data=betamean,subject='fsaverage_tk',cmap="viridis")
    data_to_plot2=cortex.Vertex(data=R2,subject='fsaverage_tk', cmap='inferno')
    #data_to_plot3=cortex.Vertex(data=HRFindex,subject='fsaverage_tk',cmap="jet")
    #data_to_plot4=cortex.Vertex(data=fracvalue,subject='fsaverage_tk',cmap="copper")
    data_to_plot5=cortex.Vertex(data=noisepool,subject='fsaverage_tk',cmap="RdBu_r",vmin=0,vmax=1)
    flatmap=cortex.quickshow(data_to_plot1)
    flatmap=cortex.quickshow(data_to_plot2)
    #flatmap=cortex.quickshow(data_to_plot3)
    #flatmap=cortex.quickshow(data_to_plot4)
    flatmap=cortex.quickshow(data_to_plot5) 
elif 'TYPEB' in test_data_path:
    #onoffR2 = test_data['onoffR2']
    R2 = test_data['R2']
    #meanvol = test_data['meanvol']
    #
    #noisepool = test_data['noisepool']
    #HRFindex = test_data['HRFindex']
    #fracvalue = test_data['FRACvalue']
    # print(test_data['meanvol'])
    #print(test_data['noisepool'].shape)
    #print(test_data['R2'].shape)
    #print(noisepool)

    betas = test_data['betasmd']
    print(betas.shape)
    # #switch the first and second dimension
    # betas = np.swapaxes(betas,0,1)

    betamean = np.mean(betas,axis=1)
    print(betamean.shape)

    # dataslice = data_for_plot[10]
    # print(dataslice.shape)

    data_to_plot1=cortex.Vertex(data=betamean,subject='fsaverage_tk',cmap="viridis")
    data_to_plot2=cortex.Vertex(data=R2,subject='fsaverage_tk', cmap='inferno')
    #data_to_plot3=cortex.Vertex(data=HRFindex,subject='fsaverage_tk',cmap="jet")
    #data_to_plot4=cortex.Vertex(data=fracvalue,subject='fsaverage_tk',cmap="copper")
    #data_to_plot5=cortex.Vertex(data=noisepool,subject='fsaverage_tk',cmap="RdBu_r",vmin=0,vmax=1)
    flatmap=cortex.quickshow(data_to_plot1)
    flatmap=cortex.quickshow(data_to_plot2)
    #flatmap=cortex.quickshow(data_to_plot3)
    #flatmap=cortex.quickshow(data_to_plot4)
    #flatmap=cortex.quickshow(data_to_plot5)
# Out:
# dict_keys(['HRFindex', 'HRFindexrun', 'glmbadness', 'pcvoxels', 'pcnum', 'xvaltrend', 'noisepool', 'pcregressors', 'betasmd', 'R2', 'R2run', 'rrbadness', 'FRACvalue', 'scaleoffset', 'meanvol'])
# HRFindex
# HRFindexrun
# glmbadness
# pcvoxels
# pcnum
# 9
# xvaltrend
# noisepool
# pcregressors
# betasmd
# R2
# R2run
# rrbadness
# FRACvalue
# scaleoffset
# meanvol
# ------------------
#
# (327684, 720)
# (327684,)

# %%
#flatmap=cortex.quickshow(data_to_plot4)

# %%
cortex.db
# Out:
# Pycortex database
#   Subjects:
#    001
#    S1
#    fsaverage_tk
#    sub-001
